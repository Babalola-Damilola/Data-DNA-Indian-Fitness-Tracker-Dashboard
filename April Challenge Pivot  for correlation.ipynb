# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Importing the dataset
c = pd.read_excel("smartwatches.xlsx")
c
# Out:
#      Index  Current Price       Brand  Original Price  Discount Percentage  \
# 0        0        82990.0       noise         89900.0             7.686318
# 1        1         3799.0  fire-boltt         16999.0            77.651627
# 2        2         1999.0        boat          7990.0            74.981227
# 3        3         1799.0  fire-boltt         19999.0            91.004550
# 4        4         1599.0       noise          4999.0            68.013603
# ..     ...            ...         ...             ...                  ...
# 445    445         5999.0  fire-boltt          8999.0            33.337037
# 446    446         3700.0  fire-boltt          9999.0            62.996300
# 447    447         5999.0  fire-boltt          8999.0            33.337037
# 448    448         3200.0  fire-boltt          7999.0            59.994999
# 449    449         3000.0  fire-boltt          7999.0            62.495312
#
# ...

# %%
# Checking datatypes
c.dtypes
# Out:
# Index                    int64
# Current Price          float64
# Brand                   object
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Model Name              object
# Dial Shape              object
# Strap Color             object
# Strap Material          object
# Touchscreen             object
# Battery Life (Days)    float64
# Bluetooth               object
# Display Size            object
# Weight                  object
# dtype: object

# %%
# convert 'Yes' to 1 and 'No' to 0 for the 'Bluetooth' and 'Touchscreen' columns
c['Bluetooth'] = c['Bluetooth'].replace({'Yes': 1, 'No': 0})
c['Touchscreen'] = c['Touchscreen'].replace({'Yes': 1, 'No': 0})
# convert Index from Int to object
c['Index'] = c['Index'].astype('object')
c.dtypes
# Out:
# Index                   object
# Current Price          float64
# Brand                   object
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Model Name              object
# Dial Shape              object
# Strap Color             object
# Strap Material          object
# Touchscreen            float64
# Battery Life (Days)    float64
# Bluetooth              float64
# Display Size            object
# Weight                  object
# dtype: object

# %%
# Storing measure/numerical column names in "measure_cols" list
measure_cols = [i for i in c.select_dtypes(include=np.number).columns]
# Storing categorical column names in "cat_cols" list
cat_cols = [i for i in c.columns if i not in measure_cols]
measure_cols
# Out:
# ['Current Price',
#  'Original Price',
#  'Discount Percentage',
#  'Rating',
#  'Number OF Ratings',
#  'Touchscreen',
#  'Battery Life (Days)',
#  'Bluetooth']

# %%
# Saving the pivoted
c.melt(id_vars=cat_cols).to_excel('smartwatces_pivot.xlsx')
# For display of the pivoted table
c.melt(id_vars=cat_cols)
# Out:
#      Index       Brand                              Model Name Dial Shape  \
# 0        0       noise   Wrb-sw-colorfitpro4alpha-std-rgld_pnk        NaN
# 1        1  fire-boltt                                  BSW046        NaN
# 2        2        boat                               Wave Call        NaN
# 3        3  fire-boltt                                  BSW053        NaN
# 4        4       noise  Wrb-sw-colorfitpulsegobuzz-std-blk_blk        NaN
# ...    ...         ...                                     ...        ...
# 3595   445  fire-boltt                                  bsw003     Circle
# 3596   446  fire-boltt                               beast pro     Square
# 3597   447  fire-boltt                                  bsw003     Circle
# 3598   448  fire-boltt                                  call 2     Square
# 3599   449  fire-boltt                                  call 2     Square
#
#      Strap Color Strap Material Display Size     Weight       variable  \
# ...
